# %%
#Ejercicio 1 de pair programming: Variables, booleanas, operadores numéricos y binarios

#Inicio del juego

saludo="Hola, guapa"
print(saludo)
print("Coloca un número entre el 3 y el 6")
numero_usuario_1=input("Escribe un número entre el 3 y el 6")
print("Intento 1:",numero_usuario_1)
print("Terminamos el juego, el número era 5 ¿lo adivinaste?")


#bonus



#Bonus
print(saludo)
print("Coloca un número entre el 3 y el 6")
intentos=0 #No sé como resolver que vaya aumentando en uno sin un bucle
print("Intento",intentos+1,":",numero_usuario_1)
print("Terminamos el juego, el número era 5 ¿lo adivinaste?")
# Out:
# Hola, guapa
# Coloca un número entre el 3 y el 6
# Intento 1:
# Terminamos el juego, el número era 5 ¿lo adivinaste?
# Hola, guapa
# Coloca un número entre el 3 y el 6
# Intento 1 :
# Terminamos el juego, el número era 5 ¿lo adivinaste?

# %%
#Ejercicio 2 de pair programming: listas 1

# Variables numéricas
lim_superior= 9
lim_inferior= 1

# Cadenas fijas de texto
str_input = "Escribe tres números separados por espacio entre el 1 y  el 9"
saludo= "Hola, guapa"

# User input
num_list = list(int(num) for num in input(str_input).strip().split())

# Cantidades calculadas
numero_secreto = random.randint(lim_inferior,lim_superior)

# Inicio del juego
print(saludo)
print(num_list)
print("La longitud de la lista es:", len(num_list),)
print("El nùmero máximo de la lista es:", max(num_list))
print("El nùmero mínimo de la lista es:", min(num_list))


# Fin del juego
# Out:
# Hola, guapa
# [9, 2, 7]
# La longitud de la lista es: 3
# El nùmero máximo de la lista es: 9
# El nùmero mínimo de la lista es: 2

# %%
# Ejercicio 3  de pair programming: listas 2

import random

# Variables numéricas
index = -1
lim_inferior= 0
lim_superior= 20
longitud_lista= 6

# Cantidades calculadas
num_list = random.sample(range(lim_inferior, lim_superior), longitud_lista)

# Cadenas fijas de texto
saludo= "Hola, guapa"
num_del_usuario= "Tu número es: "


#Inicio del juego
print(saludo)


# User input
intento= input("Coloca aquí un número del 1 al 20")

intento= int(intento) #se convierte el intento de str a int
intento_bool = intento in num_list

# Propiedades de la lista aleatoria
print("La lista aleatoria tiene", len(num_list), "números entre", min(num_list), "y", max(num_list))

print(num_del_usuario, intento)


# Han adivinado un elemento?
print( "¿Estaba en la lista aleatoria?")
print (intento_bool)
print("Tu lista es:",  num_list)

indice = num_list.index(intento)
indice_humano = indice + 1

# Si adivinaron uno, dónde estaba?
if num_list.count(indice): index = indice
if index >= 0: print("Estaba en el sitio", indice_humano, "índice", str(index)+".")

# Fin del juego
print("Terminamos el juego")
# Out:
# Hola, guapa
# La lista aleatoria tiene 6 números entre 3 y 18
# Tu número es:  20
# ¿Estaba en la lista aleatoria?
# False
# Tu lista es: [16, 8, 18, 9, 3, 7]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/feliciano/Documents/Adalab/ejercicios-de-adalab/modulo_1_pairprogramming/Adalab-DA-promo-b-modulo-1-sprint-1-Yadira-Diana/pairprogramming_1.ipynb Celda 3 in <cell line: 40>()
#      <a href='vscode-notebook-cell:/Users/feliciano/Documents/Adalab/ejercicios-de-adalab/modulo_1_pairprogramming/Adalab-DA-promo-b-modulo-1-sprint-1-Yadira-Diana/pairprogramming_1.ipynb#ch0000002?line=36'>37</a> print (intento_bool)
#      <a href='vscode-notebook-cell:/Users/feliciano/Documents/Adalab/ejercicios-de-adalab/modulo_1_pairprogramming/Adalab-DA-promo-b-modulo-1-sprint-1-Yadira-Diana/pairprogramming_1.ipynb#ch0000002?line=37'>38</a> print("Tu lista es:",  num_list)
# ...

# %%
#Ejercicio 4 pair programming: Diccionarios

import random

words = {'Colors':'red orange yellow green blue indigo violet white black brown'.split(),
'Shapes':'square triangle rectangle circle ellipse rhombus trapezoid chevron pentagon hexagon septagon octagon'.split(),
'Fruits':'apple orange lemon lime pear watermelon grape grapefruit cherry banana cantaloupe mango strawberry tomato'.split(),
'Animals':'bat bear beaver cat cougar crab deer dog donkey duck eagle fish frog goat leech lion lizard monkey moose mouse otter owl panda python rabbit rat shark sheep skunk squid tiger turkey turtle weasel whale wolf wombat zebra'.split()}

# Variables predefinidas
saludo= "Hola, guapa"
eleccion_key= "Elige una de las siguientes categorias, usando su número."
eleccion_value= "Adivina una palabra de la categoria:"
adivinaste= "Era la palabra que buscabamos?"



word_list= {1:'Colors', 2: 'Shapes', 3: 'Fruits', 4: 'Animals'}

# Inicio del juego
print(saludo)
print(eleccion_key)
eleccion_usuario_1=input(word_list)
eleccion_usuario_1= int(eleccion_usuario_1)

#eleccion_usuario_2= input(words)


#eleccion_bool = eleccion_usuario_1 in word_list

# Elegir una categoria
print("Elegiste la categoria ", eleccion_usuario_1)

categoria_elegida= word_list.get(eleccion_usuario_1)
print( eleccion_value, categoria_elegida)

values_del_diccionario= words.values()

# Adivinar una palabra

eleccion_usuario_2=input("Coloca una palabra de la categoría que elegiste:")


# Era la palabra aleatoria?

print(eleccion_usuario_2 in words[categoria_elegida])


# Fin del juego

print("Terminamos el juego, tu palabra era", eleccion_usuario_2)
# Out:
# Hola, guapa
# Elige una de las siguientes categorias, usando su número.
# Elegiste la categoria  2
# Adivina una palabra de la categoria: Shapes
# False
# Terminamos el juego, tu palabra era bear

# %%
#Ejercicio 4 pair programming: Diccionarios (Versión Yadi)
import random


# Variables predefinidas
        #El diccionario
words = {'Colors':'red orange yellow green blue indigo violet white black brown'.split(),
'Shapes':'square triangle rectangle circle ellipse rhombus trapezoid chevron pentagon hexagon septagon octagon'.split(),
'Fruits':'apple orange lemon lime pear watermelon grape grapefruit cherry banana cantaloupe mango strawberry tomato'.split(),
'Animals':'bat bear beaver cat cougar crab deer dog donkey duck eagle fish frog goat leech lion lizard monkey moose mouse otter owl panda python rabbit rat shark sheep skunk squid tiger turkey turtle weasel whale wolf wombat zebra'.split()}
saludo= "Hola, guapa"
msj_key="Elige una de las siguientes categorias, usando su número."

word_list=list (words.keys())
diccionario_keys= {1:'Colors', 2: 'Shapes', 3: 'Fruits', 4: 'Animals'}
adivina="Adivina una palabra de la categoria"
palabra="Elegiste la palabra:"
pregunta='¿Adivinaste la palabra?'
fin_juego="Terminamos el juego"
# Inicio del juego
print(saludo)
print(msj_key)
print(diccionario_keys)
numero_usuario=input(word_list)
numero_usuario= int(numero_usuario)

# Elegir una categoria
print("Elegiste la categoria ", numero_usuario)
numero_usuario=numero_usuario-1 #aqui se cambia a tipo int
values_elegidos= word_list[numero_usuario] #Aqui se guarda en la variable los values de la categoría que seleccionó el usuario

values_diccionario=words[values_elegidos]#Esta es la lista de las values

#print(values_del_diccionario)
value_del_usuario=input(values_diccionario)



# El ordenador elige una palabra de la categoria

word_secreta =random.randint(0,len(word_list)-1)
word_secreta2=values_diccionario[word_secreta]


# Adivinar una palabra
print(adivina)
print(palabra,value_del_usuario)

# Era la palabra aleatoria?
print(pregunta)
#value_del_usuario in word_secreta
print(value_del_usuario == word_secreta2)

# Fin del juego
print(fin_juego, "La palabra era:", word_secreta2)
# Out:
# Hola, guapa
# Elige una de las siguientes categorias, usando su número.
# {1: 'Colors', 2: 'Shapes', 3: 'Fruits', 4: 'Animals'}
# Elegiste la categoria  1
# Adivina una palabra de la categoria
# Elegiste la palabra: white
# ¿Adivinaste la palabra?
# False
# Terminamos el juego La palabra era: orange
